# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\amanr\OneDrive\Documents\high_value_customers (2).csv",encoding ="ISO-8859-1")

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# 0        29-Nov-16       2.55     17850.0  United Kingdom
# 1        29-Nov-16       3.39     17850.0  United Kingdom
# 2        29-Nov-16       2.75     17850.0  United Kingdom
# 3        29-Nov-16       3.39     17850.0  United Kingdom
# 4        29-Nov-16       3.39     17850.0  United Kingdom
# ...            ...        ...         ...             ...
# 541904   07-Dec-17       0.85     12680.0          France
# 541905   07-Dec-17       2.10     12680.0          France
# 541906   07-Dec-17       4.15     12680.0          France
# 541907   07-Dec-17       4.15     12680.0          France
# 541908   07-Dec-17       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
df.dropna()
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country
# 0   29-Nov-16       2.55     17850.0  United Kingdom
# 1   29-Nov-16       3.39     17850.0  United Kingdom
# 2   29-Nov-16       2.75     17850.0  United Kingdom
# 3   29-Nov-16       3.39     17850.0  United Kingdom
# 4   29-Nov-16       3.39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.isnull().mean()*100
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.268311
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     24.926694
# Country         0.000000
# dtype: float64

# %%
#Removing the Null values from the data.
df = df[pd.notnull(df['CustomerID'])]

# %%
#Excluding Negative Values in Quantity and UnitPrice
df = df[(df.Quantity>0) & (df.UnitPrice>0)]

# %%
#Returned items indicated with C so we can drop them by filtering 
df = df[~df['StockCode'].str.contains('C')]

# %%
#Dropping Duplicated Values
df = df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df.Country.value_counts(normalize=True).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df = df[df.Country == 'United Kingdom']

# %%
print('Orders from {} to {}'.format(df['InvoiceDate'].min(),
                                    df['InvoiceDate'].max()))
# Out:
# Orders from 01-Apr-17 to 31-Oct-17

# %%
df["Total Revenue"] = df['Quantity']*df['UnitPrice']
Monetary = df.groupby('CustomerID')['Total Revenue'].sum()
Monetary = Monetary.reset_index()
Monetary.head()
# Out:
#    CustomerID  Total Revenue
# 0     12346.0       77183.60
# 1     12747.0        4128.71
# 2     12748.0       32509.54
# 3     12749.0        4014.18
# 4     12820.0         942.34

# %%
Frequency = df.groupby('CustomerID')['InvoiceNo'].count()
Frequency = Frequency.reset_index()
Frequency.head()
# Out:
#    CustomerID  InvoiceNo
# 0     12346.0          1
# 1     12747.0        100
# 2     12748.0       4345
# 3     12749.0        196
# 4     12820.0         59

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['InvoiceYearMonth'] = df['InvoiceDate'].map(lambda date: 100*date.year + date.month)
df['Date'] = df['InvoiceDate'].dt.strftime('%Y-%m')
df['diff'] = max(df['InvoiceDate'])-df['InvoiceDate']
Recency = df.groupby('CustomerID')['diff'].min()

Recency = Recency.reset_index()
Recency.head()
# Out:
#    CustomerID     diff
# 0     12346.0 325 days
# 1     12747.0   2 days
# 2     12748.0   0 days
# 3     12749.0   3 days
# 4     12820.0   3 days

# %%
Recency['diff'] = Recency['diff'].dt.days
Recency.head()
# Out:
#    CustomerID  diff
# 0     12346.0   325
# 1     12747.0     2
# 2     12748.0     0
# 3     12749.0     3
# 4     12820.0     3

# %%
rfm = pd.merge(Recency, Frequency, on = "CustomerID", how = "inner")

# %%
rfm = pd.merge(rfm, Monetary, on="CustomerID", how = "inner")

# %%
rfm.columns = ["CustomerID", 'Recency', 'Frequency', 'Monetary']

# %%
rfm
# Out:
#       CustomerID  Recency  Frequency  Monetary
# 0        12346.0      325          1  77183.60
# 1        12747.0        2        100   4128.71
# 2        12748.0        0       4345  32509.54
# 3        12749.0        3        196   4014.18
# 4        12820.0        3         59    942.34
# ...          ...      ...        ...       ...
# 3910     18280.0      277         10    180.60
# 3911     18281.0      180          7     80.82
# 3912     18282.0        7         12    178.05
# 3913     18283.0        3        720   2041.78
# 3914     18287.0       42         69   1821.98
#
# [3915 rows x 4 columns]

# %%
rfm["R"] = pd.qcut(rfm["Recency"],5,labels=[5,4,3,2,1])
rfm["F"] = pd.qcut(rfm["Frequency"],5,labels=[1,2,3,4,5])
rfm["M"] = pd.qcut(rfm["Monetary"],5,labels=[1,2,3,4,5])
rfm["RFM_Score"] = rfm["R"].astype(str) +rfm["F"].astype(str) + rfm["M"].astype(str)

# %%
rfm
# Out:
#       CustomerID  Recency  Frequency  Monetary  R  F  M RFM_Score
# 0        12346.0      325          1  77183.60  1  1  5       115
# 1        12747.0        2        100   4128.71  5  4  5       545
# 2        12748.0        0       4345  32509.54  5  5  5       555
# 3        12749.0        3        196   4014.18  5  5  5       555
# 4        12820.0        3         59    942.34  5  4  4       544
# ...          ...      ...        ...       ... .. .. ..       ...
# 3910     18280.0      277         10    180.60  1  1  1       111
# 3911     18281.0      180          7     80.82  1  1  1       111
# 3912     18282.0        7         12    178.05  5  1  1       511
# 3913     18283.0        3        720   2041.78  5  5  5       555
# 3914     18287.0       42         69   1821.98  3  4  4       344
#
# [3915 rows x 8 columns]

# %%
seg_map = {
    r'[1-2][1-2]': 'Hibernating',
    r'[1-2][3-4]': 'At Risk',
    r'[1-2]5': 'Can\'t Loose',
    r'3[1-2]': 'About to sleep',
    r'33': 'Need Attention',
    r'[3-4][4-5]': 'Loyal Customers',
    r'41': 'Promising',
    r'51': 'New Customers',
    r'[3-4][4-5]': 'Potential Loyalists',
    r'5[4-5]': 'Champions'
}

# %%
rfm['Segment'] = rfm['R'].astype(str) + rfm['F'].astype(str)
rfm['Segment'] = rfm['Segment'].replace(seg_map, regex=True)
rfm.head()
# Out:
#    CustomerID  Recency  Frequency  Monetary  R  F  M RFM_Score      Segment
# 0     12346.0      325          1  77183.60  1  1  5       115  Hibernating
# 1     12747.0        2        100   4128.71  5  4  5       545    Champions
# 2     12748.0        0       4345  32509.54  5  5  5       555    Champions
# 3     12749.0        3        196   4014.18  5  5  5       555    Champions
# 4     12820.0        3         59    942.34  5  4  4       544    Champions

# %%
rfm.groupby('Segment').mean().sort_values('Monetary')
# Out:
#                        CustomerID     Recency   Frequency     Monetary
# Segment
# About to sleep       15525.787671   52.219178   15.267123   435.219486
# Promising            15496.234694   22.428571    7.183673   445.777347
# 42                   15568.939130   22.391304   20.904348   522.877913
# Hibernating          15529.887500  207.501042   12.985417   537.732126
# 52                   15396.045455    5.939394   21.000000   683.968939
# 43                   15539.967320   22.379085   42.562092   811.152490
# Need Attention       15809.184615   51.410256   40.523077   815.458821
# At Risk              15573.109615  167.796154   55.523077   884.872462
# 53                   15569.247934    6.421488   42.247934  1410.017273
# Can't Loose          15891.676056  145.901408  180.098592  2268.055930
# Potential Loyalists  15597.416321   33.410788  152.181189  2428.635339
# New Customers        15577.375000    6.145833    7.062500  4111.827083
# Champions            15491.336347    5.471971  275.750452  6129.221971

# %%
file_name = 'rfm_df1.xlsx'
rfm.to_excel(file_name)
print('DataFrame is written to Excel')
# Out:
# DataFrame is written to Excel
